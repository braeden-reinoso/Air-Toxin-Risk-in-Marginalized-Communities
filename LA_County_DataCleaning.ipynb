# %% [markdown]
# **Data Cleaning for LA county census data**

# %%
import pandas as pd

# %%
la_county_df = pd.read_csv('./data/census_data/LA_County_Data.csv', low_memory=False)

# %%
la_county_df.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0             Geography                               Geographic Area Name
# 1  1400000US06037101110  Census Tract 1011.10, Los Angeles County, Cali...
# 2  1400000US06037101122  Census Tract 1011.22, Los Angeles County, Cali...
# 3  1400000US06037101220  Census Tract 1012.20, Los Angeles County, Cali...
# 4  1400000US06037101221  Census Tract 1012.21, Los Angeles County, Cali...
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                     3879
# 2                                     4247
# 3                                     3583
# 4                                     3723
#
#                                          DP05_0001EA  \
# 0  Annotation of Estimate!!SEX AND AGE!!Total pop...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
la_county_df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 715 columns):
#  #    Column        Non-Null Count  Dtype
# ---   ------        --------------  -----
#  0    GEO_ID        2499 non-null   object
#  1    NAME          2499 non-null   object
#  2    DP05_0001E    2499 non-null   object
#  3    DP05_0001EA   1 non-null      object
#  4    DP05_0001M    2499 non-null   object
#  5    DP05_0001MA   1 non-null      object
#  6    DP05_0002E    2499 non-null   object
#  7    DP05_0002M    2499 non-null   object
#  8    DP05_0002MA   1 non-null      object
#  9    DP05_0002EA   1 non-null      object
#  10   DP05_0003E    2499 non-null   object
#  11   DP05_0003M    2499 non-null   object
#  12   DP05_0003MA   1 non-null      object
#  13   DP05_0003EA   1 non-null      object
#  14   DP05_0004E    2499 non-null   object
#  15   DP05_0004M    2499 non-null   object
#  16   DP05_0004MA   25 non-null     object
# ...

# %%
la_county_df.dropna(axis=1, inplace=True)
la_county_df.head()
# Out:
#                  GEO_ID                                               NAME  \
# 0             Geography                               Geographic Area Name
# 1  1400000US06037101110  Census Tract 1011.10, Los Angeles County, Cali...
# 2  1400000US06037101122  Census Tract 1011.22, Los Angeles County, Cali...
# 3  1400000US06037101220  Census Tract 1012.20, Los Angeles County, Cali...
# 4  1400000US06037101221  Census Tract 1012.21, Los Angeles County, Cali...
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                     3879
# 2                                     4247
# 3                                     3583
# 4                                     3723
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                             480
# 2                                             875
# ...

# %%
la_county_data = la_county_df[['GEO_ID', 'NAME', 'DP05_0063E', 'DP05_0063M', 'DP05_0064E', 'DP05_0064M',
                              'DP05_0065E', 'DP05_0065M', 'DP05_0067E', 'DP05_0067M', 'DP05_0071E', 'DP05_0071M']]
la_county_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GEO_ID      2499 non-null   object
#  1   NAME        2499 non-null   object
#  2   DP05_0063E  2499 non-null   object
#  3   DP05_0063M  2499 non-null   object
#  4   DP05_0064E  2499 non-null   object
#  5   DP05_0064M  2499 non-null   object
#  6   DP05_0065E  2499 non-null   object
#  7   DP05_0065M  2499 non-null   object
#  8   DP05_0067E  2499 non-null   object
#  9   DP05_0067M  2499 non-null   object
#  10  DP05_0071E  2499 non-null   object
#  11  DP05_0071M  2499 non-null   object
# dtypes: object(12)
# memory usage: 234.4+ KB

# %%
la_county_data
# Out:
#                     GEO_ID                                               NAME  \
# 0                Geography                               Geographic Area Name
# 1     1400000US06037101110  Census Tract 1011.10, Los Angeles County, Cali...
# 2     1400000US06037101122  Census Tract 1011.22, Los Angeles County, Cali...
# 3     1400000US06037101220  Census Tract 1012.20, Los Angeles County, Cali...
# 4     1400000US06037101221  Census Tract 1012.21, Los Angeles County, Cali...
# ...                    ...                                                ...
# 2494  1400000US06037980038  Census Tract 9800.38, Los Angeles County, Cali...
# 2495  1400000US06037980039  Census Tract 9800.39, Los Angeles County, Cali...
# 2496  1400000US06037990100  Census Tract 9901, Los Angeles County, California
# 2497  1400000US06037990200  Census Tract 9902, Los Angeles County, California
# 2498  1400000US06037990300  Census Tract 9903, Los Angeles County, California
#
# ...

# %%
la_county_data.columns = la_county_data.iloc[0]

# %%
la_county_final = la_county_data.drop(la_county_data.index[0])

# %%
la_county_final.reset_index(drop=True, inplace=True)
la_county_final
# Out:
# 0                Geography                               Geographic Area Name  \
# 0     1400000US06037101110  Census Tract 1011.10, Los Angeles County, Cali...
# 1     1400000US06037101122  Census Tract 1011.22, Los Angeles County, Cali...
# 2     1400000US06037101220  Census Tract 1012.20, Los Angeles County, Cali...
# 3     1400000US06037101221  Census Tract 1012.21, Los Angeles County, Cali...
# 4     1400000US06037101222  Census Tract 1012.22, Los Angeles County, Cali...
# ...                    ...                                                ...
# 2493  1400000US06037980038  Census Tract 9800.38, Los Angeles County, Cali...
# 2494  1400000US06037980039  Census Tract 9800.39, Los Angeles County, Cali...
# 2495  1400000US06037990100  Census Tract 9901, Los Angeles County, California
# 2496  1400000US06037990200  Census Tract 9902, Los Angeles County, California
# 2497  1400000US06037990300  Census Tract 9903, Los Angeles County, California
#
# ...

# %%
la_county_final.columns = ['Geography', 'Geographic Area Name', 'Total population', 'Error!Total population', 'Total population!!White',
                                'Error!Total population!!White', 'Total population!!Black or African American', 'Error!Total population!!Black or African American',
                                'Total population!!Asian', 'Error!Total population!!Asian',
                                'Total population!!Hispanic or Latino (of any race)', 'Error!Total population!!Hispanic or Latino (of any race)']
la_county_final.head()
# Out:
#               Geography                               Geographic Area Name  \
# 0  1400000US06037101110  Census Tract 1011.10, Los Angeles County, Cali...
# 1  1400000US06037101122  Census Tract 1011.22, Los Angeles County, Cali...
# 2  1400000US06037101220  Census Tract 1012.20, Los Angeles County, Cali...
# 3  1400000US06037101221  Census Tract 1012.21, Los Angeles County, Cali...
# 4  1400000US06037101222  Census Tract 1012.22, Los Angeles County, Cali...
#
#   Total population Error!Total population Total population!!White  \
# 0             3879                    480                    3174
# 1             4247                    875                    3272
# 2             3583                    486                    2531
# 3             3723                    721                    2685
# 4             2690                    520                    2443
#
#   Error!Total population!!White Total population!!Black or African American  \
# ...

# %%
la_county_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 12 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Geography                                                 2498 non-null   object
#  1   Geographic Area Name                                      2498 non-null   object
#  2   Total population                                          2498 non-null   object
#  3   Error!Total population                                    2498 non-null   object
#  4   Total population!!White                                   2498 non-null   object
#  5   Error!Total population!!White                             2498 non-null   object
#  6   Total population!!Black or African American               2498 non-null   object
#  7   Error!Total population!!Black or African American         2498 non-null   object
# ...

# %%
la_county_final.iloc[:, 2:].astype(int).describe()
# Out:
#        Total population  Error!Total population  Total population!!White  \
# count        2498.00000             2498.000000              2498.000000
# mean         4011.06285              602.570056              2128.285028
# std          1470.99188              242.111108              1139.757866
# min             0.00000                6.000000                 0.000000
# 25%          2993.25000              441.250000              1300.500000
# 50%          3933.00000              577.000000              1971.500000
# 75%          4954.00000              736.750000              2778.750000
# max         13830.00000             2223.000000              7864.000000
#
#        Error!Total population!!White  \
# count                    2498.000000
# mean                      496.698559
# std                       232.646368
# min                         4.000000
# 25%                       339.000000
# 50%                       465.000000
# 75%                       615.000000
# ...

# %%
la_county_final.to_csv("./data/census_data/LA_County_Cleaned_Data.csv", index=False)
