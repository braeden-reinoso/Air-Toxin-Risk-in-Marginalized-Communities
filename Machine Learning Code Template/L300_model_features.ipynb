# %% [markdown]
# # Product Matching
# ## Level 3: Model Feature Creation Script
#
# ### Notes:
# 1. Create all candidate predictor variables
#
# ### References:

# %% [markdown]
# ## Notebook Config

# %%
# Display settings
## Auto reload modules & inline plots
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Package Import & Initialization

# %%
# Import packages

import pandas as pd                  #For data manipulation and bgq --> pandas conversion
import numpy as np                   #For scientific computation
import os                            #For work with native operating system and directories
from pathlib import Path             #For working with file paths and directories
import warnings                      #To tweak warning options
import datetime as dt                #For date objects and implemetations
import joblib                        #For saving objects, more efficient at serializing large numpy arrays than pickle module
from sklearn.preprocessing import StandardScaler, PolynomialFeatures  #For standardizing/tranforming numeric variables

# %%
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:.4f}'.format
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Function Library

# %% [markdown]
# ## Custom Tranformers

# %% [markdown]
# ## Set Directories

# %%
#cwd = os.getcwd()
#os.chdir(cwd)
home = str(Path.home())
proj_path = os.path.join(home, 'Cardinal Health', 'Enterprise Data Remediation - Documents', 'General', '01_Projects', 
                         '23_Kinaxis')

# %%
main_dir = proj_path + '\\'
iput_dir = main_dir + 'Data\\Output\\ML\\'
oput_dir = main_dir + 'Data\\Output\\ML\\'

# %% [markdown]
# ## Set Output File Names

# %%
## Output file name
feat_oput_file_name = "L300_feat_df_" + str(dt.datetime.today().strftime('%Y-%m-%d')) + '.pkl'
prd_oput_file_name  = "L300_prd_df_" + str(dt.datetime.today().strftime('%Y-%m-%d')) + '.pkl'
tgt_oput_file_name  = "L300_tgt_df_" + str(dt.datetime.today().strftime('%Y-%m-%d')) + '.pkl'
sclr_oput_file_name = "L300_sclr_obj_" + str(dt.datetime.today().strftime('%Y-%m-%d')) + '.pkl'

# %% [markdown]
# ## Load Data

# %%
raw_df = pd.read_pickle(iput_dir + "L100_trn_df_2022-07-15.pkl")

# %% [markdown]
# ## High-level Data Inspection

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1668 entries, 0 to 1667
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ITEMNUMBER              1668 non-null   object
#  1   Number                  1668 non-null   object
#  2   ITEMDESCRIPTION         1668 non-null   object
#  3   FullDescription         1668 non-null   object
#  4   SUPPLIER_ITEM_NUMBER    1668 non-null   object
#  5   ManufacturerItemNumber  1668 non-null   object
#  6   SUPPLIERNAME            1668 non-null   object
#  7   ManufacturerName        1668 non-null   object
#  8   UNSPCCode               1646 non-null   float64
#  9   UNSPSC                  1668 non-null   int64
#  10  Feat_1                  1668 non-null   int64
#  11  Feat_2                  1668 non-null   int64
#  12  Feat_3                  1668 non-null   int64
#  13  Feat_4                  1668 non-null   int64
#  14  Feat_5                  1668 non-null   int64
#  15  Match_Confidence        1668 non-null   object
#  16  Match                   1668 non-null   object
#  17  Comments                4 non-null      object
#  18  Unnamed: 17             0 non-null      object
#  19  Feat_6                  1668 non-null   int32
# dtypes: float64(1), int32(1), int64(6), object(12)
# memory usage: 254.2+ KB

# %%
raw_df.head()
# Out:
#   ITEMNUMBER   Number                                    ITEMDESCRIPTION  \
# 0   58305122   305106          Regular Bevel Needle 25Gx5/8" (100 count)
# 1     683208  A5000-1                      Lisco Nonsterile Sponge 4"x4"
# 2     682733     2733               Curity Nonsterile Gauze Sponge 4"x4"
# 3     686132     8043            CURITY Sterile Gauze Pad, 3"x3", 12 ply
# 4   58309642   309642  Luer-Lok Syringe with Detachable PrecisionGlid...
#
#                                      FullDescription SUPPLIER_ITEM_NUMBER  \
# 0  NEEDLE HYPO REGULAR BEVEL 30GX 0.5IN 100/PK 10...               305122
# 1  APPLICATOR WOODEN NO TIP 6IN NONSTERILE 1000EA...                 3208
# 2                   GAUZE SPONGE 4X4IN 16PLY 2000/CS                2733-
# 3  GAUZE SPONGE CURITY 3X3 4PLY LF STER 2EA/PK 25...                 6132
# 4        SYRINGE LUER LOK 10ML 21G 1IN 100/PK 4PK/CS               309642
#
#   ManufacturerItemNumber               SUPPLIERNAME  ManufacturerName  \
# 0                 305106  BECTON DICKINSON CONSUMER  BECTON DICKINSON
# 1                A5000-1         CARDINAL HEALTH-PR   CARDINAL HEALTH
# 2                  2733-         CARDINAL HEALTH-PR   CARDINAL HEALTH
# 3                   8043         CARDINAL HEALTH-PR   CARDINAL HEALTH
# 4                 309642  BECTON DICKINSON CONSUMER  BECTON DICKINSON
#
#       UNSPCCode    UNSPSC  Feat_1  Feat_2  Feat_3  Feat_4  Feat_5  \
# 0 42142523.0000  42142523       0     100      77       0       1
# 1 42311512.0000  42141502       0     100      53       0       0
# 2 42311512.0000  42311512       1     100      55       0       1
# 3 42311512.0000  42311512       0     100      57       0       1
# 4 42142609.0000  42142609       1     100      63       0       1
#
#   Match_Confidence Match Comments Unnamed: 17  Feat_6
# 0           02 Med    No      NaN         NaN       0
# 1           03 Low    No      NaN         NaN       0
# 2          01 High   Yes      NaN         NaN       1
# 3           03 Low    No      NaN         NaN       0
# 4          01 High   Yes      NaN         NaN       1

# %% [markdown]
# ## Feature Creation

# %%
## Reformat certain column variables (e.g. UNSPSC)

# %%
## Custom Feature Creation
raw_feat_df = (
    raw_df
    .rename(columns = dict(zip(
        ['Feat_1','Feat_2','Feat_3','Feat_4','Feat_5','Feat_6'],
        ['Feat_Exact_SuppItemNum','Feat_Fuzzy_SuppName','Feat_Fuzzy_ItemDesc','Feat_Exact_ItemNum','Feat_Exact_UNSPSC', 'Feat_Fuzzy_SuppItemNum']
    )))
)

# %%
raw_feat_df
# Out:
#        ITEMNUMBER    Number  \
# 0        58305122    305106
# 1          683208   A5000-1
# 2          682733      2733
# 3          686132      8043
# 4        58309642    309642
# ...           ...       ...
# 1663     58309588    305270
# 1664     55001203  55001203
# 1665        GL511     GL511
# 1666  552D72PL65X    CFN66A
# 1667      ZG702NB   ZG702NB
#
#                                         ITEMDESCRIPTION  \
# 0             Regular Bevel Needle 25Gx5/8" (100 count)
# 1                         Lisco Nonsterile Sponge 4"x4"
# 2                  Curity Nonsterile Gauze Sponge 4"x4"
# 3               CURITY Sterile Gauze Pad, 3"x3", 12 ply
# 4     Luer-Lok Syringe with Detachable PrecisionGlid...
# ...                                                 ...
# 1663  Luer-Lok Syringe with Detachable PrecisionGlid...
# 1664                 AirLife Adult Vinyl Oxygen Mask 7'
# 1665  Surgilast Tubular Elastic Dressing Retainer, S...
# 1666  Protexis PI Classic Sterile Polyisoprene Powde...
# 1667  Cardinal Health Essentials Tubular Elastic Str...
#
#                                         FullDescription SUPPLIER_ITEM_NUMBER  \
# 0     NEEDLE HYPO REGULAR BEVEL 30GX 0.5IN 100/PK 10...               305122
# 1     APPLICATOR WOODEN NO TIP 6IN NONSTERILE 1000EA...                 3208
# 2                      GAUZE SPONGE 4X4IN 16PLY 2000/CS                2733-
# 3     GAUZE SPONGE CURITY 3X3 4PLY LF STER 2EA/PK 25...                 6132
# 4           SYRINGE LUER LOK 10ML 21G 1IN 100/PK 4PK/CS               309642
# ...                                                 ...                  ...
# 1663  SYRINGE 3ML W/DETACHABLE NEEDLE 1IN 25G 100/PK...               309588
# 1664                  AirLife Adult Vinyl Oxygen Mask 7               001203
# 1665                   RETAINER DRESSINGTUBULAR ELASTIC               GL-511
# 1666   TUBING SURGICAL SUCTION 6MM 6FT STERILE 45/BX=CS            2D72PL65X
# 1667                RELIAMED TUBE NET DRSG, NS,LTX,25YD                702NB
#
#      ManufacturerItemNumber               SUPPLIERNAME  \
# 0                    305106  BECTON DICKINSON CONSUMER
# 1                   A5000-1         CARDINAL HEALTH-PR
# 2                     2733-         CARDINAL HEALTH-PR
# 3                      8043         CARDINAL HEALTH-PR
# 4                    309642  BECTON DICKINSON CONSUMER
# ...                     ...                        ...
# 1663                 305270  BECTON DICKINSON CONSUMER
# 1664               55001203             VYAIRE MEDICAL
# 1665                  GL511       INTEGRA LIFESCIENCES
# 1666                   N66A      CARDINAL HEALTH - MED
# 1667                ZG702NB      YASCO ENTERPRISE CORP
#
#                     ManufacturerName     UNSPCCode    UNSPSC  \
# 0                   BECTON DICKINSON 42142523.0000  42142523
# 1                    CARDINAL HEALTH 42311512.0000  42141502
# 2                    CARDINAL HEALTH 42311512.0000  42311512
# 3                    CARDINAL HEALTH 42311512.0000  42311512
# 4                   BECTON DICKINSON 42142609.0000  42142609
# ...                              ...           ...       ...
# 1663                BECTON DICKINSON 42142609.0000  42142609
# 1664              RGH ENTERPRISE INC 42271708.0000  42271708
# 1665  INTEGRA LIFESCIENCES SALES LLC 42311543.0000  42311543
# 1666                 CARDINAL HEALTH 42132205.0000  42293515
# 1667                   ASSURAMED INC 42311543.0000  42311543
#
#       Feat_Exact_SuppItemNum  Feat_Fuzzy_SuppName  Feat_Fuzzy_ItemDesc  \
# 0                          0                  100                   77
# 1                          0                  100                   53
# 2                          1                  100                   55
# 3                          0                  100                   57
# 4                          1                  100                   63
# ...                      ...                  ...                  ...
# 1663                       0                  100                   71
# 1664                       0                   31                  100
# 1665                       0                  100                   67
# 1666                       0                  100                   50
# 1667                       0                   24                   38
#
#       Feat_Exact_ItemNum  Feat_Exact_UNSPSC Match_Confidence Match Comments  \
# 0                      0                  1           02 Med    No      NaN
# 1                      0                  0           03 Low    No      NaN
# 2                      0                  1          01 High   Yes      NaN
# 3                      0                  1           03 Low    No      NaN
# 4                      0                  1          01 High   Yes      NaN
# ...                  ...                ...              ...   ...      ...
# 1663                   0                  1           02 Med    No      NaN
# 1664                   1                  1           03 Low   Yes      NaN
# 1665                   1                  1           03 Low   Yes      NaN
# 1666                   0                  0           03 Low    No      NaN
# 1667                   1                  1           03 Low   Yes      NaN
#
#      Unnamed: 17  Feat_Fuzzy_SuppItemNum
# 0            NaN                       0
# 1            NaN                       0
# 2            NaN                       1
# 3            NaN                       0
# 4            NaN                       1
# ...          ...                     ...
# 1663         NaN                       0
# 1664         NaN                       1
# 1665         NaN                       1
# 1666         NaN                       0
# 1667         NaN                       1
#
# [1668 rows x 20 columns]

# %%
## Create Standard Scale copies

# %% [markdown]
# ## Predictor Target Split

# %%
# Step 1. Select the predictors
X = raw_feat_df.filter(regex='^Feat', axis="columns").values

# %%
# Step 1. Select the target
# Step 2. Numericize target
y = raw_feat_df.assign(Match = lambda df: np.where(df.Match=='Yes', 1, 0)).Match

# %% [markdown]
# ## Transformers

# %%
X_scaler = StandardScaler().fit(X)

# %% [markdown]
# ## Save Data to Modeling Environment

# %%
raw_feat_df.to_pickle(oput_dir + feat_oput_file_name)

# %%
joblib.dump(X, oput_dir + prd_oput_file_name)
# Out:
# ['C:\\Users\\kehinde.salau\\Cardinal Health\\Enterprise Data Remediation - Documents\\General\\01_Projects\\23_Kinaxis\\Data\\Output\\ML\\L300_prd_df_2022-07-15.pkl']

# %%
joblib.dump(y, oput_dir + tgt_oput_file_name)
# Out:
# ['C:\\Users\\kehinde.salau\\Cardinal Health\\Enterprise Data Remediation - Documents\\General\\01_Projects\\23_Kinaxis\\Data\\Output\\ML\\L300_tgt_df_2022-07-15.pkl']

# %%
joblib.dump(X_scaler, oput_dir + sclr_oput_file_name)
# Out:
# ['C:\\Users\\kehinde.salau\\Cardinal Health\\Enterprise Data Remediation - Documents\\General\\01_Projects\\23_Kinaxis\\Data\\Output\\ML\\L300_sclr_obj_2022-07-15.pkl']
