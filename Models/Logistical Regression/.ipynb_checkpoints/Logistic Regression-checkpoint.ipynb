# %%
## For data handling
import pandas as pd
import numpy as np

## For plotting
import matplotlib.pyplot as plt
import seaborn as sns

## This sets the plot style
## to have a grid on a white background
sns.set_style("whitegrid")
# Out:
# /Users/zoekearney/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# read in the final dataset 
df = pd.read_csv('../../data/cenus_epa_climate_theil_merged.csv')

# %%
for i in df.columns:
    print(i)
# Out:
# ID
# NAME
# pop_tot
# pop_white_only
# pop_black_only
# pop_amInd_alNat_only
# pop_asian_only
# pop_natHI_PI_only
# pop_white
# pop_black
# pop_amInd_alNat
# pop_asian
# pop_natHI_PI
# pop_hispanic_latino_any
# poverty_tot_white_only
# poverty_tot_black_only
# poverty_tot_amInd_alNat_only
# poverty_tot_asian_only
# poverty_tot_natHI_PI_only
# poverty_tot_hispanic_latino_any
# poverty_below_white_only
# poverty_below_black_only
# poverty_below_amInd_alNat_only
# poverty_below_asian_only
# poverty_below_natHI_PI_only
# poverty_below_hispanic_latino_any
# poverty_below_white_only.1
# poverty_perc_black_only
# poverty_perc_amInd_alNat_only
# poverty_perc_asian_only
# poverty_perc_natHI_PI_only
# poverty_perc_hispanic_latino_any
# industry_tot
# industry_ag_for
# industry_const
# industry_manu
# industry_wtrade
# industry_rtrade
# industry_transp
# industry_info
# industry_fin
# industry_prof
# industry_ed_hc
# industry_arts_ent
# industry_other
# industry_pub_admin
# income_tot
# ...

# %%
df_urban = df[df.pop_density >= 500]
df_urban = df_urban.reset_index(drop=True)

# %%
df_urban
# Out:
#                 ID                                              NAME  pop_tot  \
# 0       1001020200         Census Tract 202, Autauga County, Alabama   2010.0
# 1       1001020300         Census Tract 203, Autauga County, Alabama   3577.0
# 2       1001020400         Census Tract 204, Autauga County, Alabama   3802.0
# 3       1001020501      Census Tract 205.01, Autauga County, Alabama   4381.0
# 4       1001020502      Census Tract 205.02, Autauga County, Alabama   3328.0
# ...            ...                                               ...      ...
# 49924  56033000400          Census Tract 4, Sheridan County, Wyoming   5489.0
# 49925  56037970602  Census Tract 9706.02, Sweetwater County, Wyoming   3364.0
# 49926  56037970902  Census Tract 9709.02, Sweetwater County, Wyoming   5348.0
# 49927  56039967801       Census Tract 9678.01, Teton County, Wyoming   3134.0
# 49928  56043000301       Census Tract 3.01, Washakie County, Wyoming   2208.0
#
# ...

# %%
# set up the classificaiton of PM2.5 
# Anything greater than 9 is considered dangerous 

pm25_class = 
pm25 = df_urban['PM25']

# %%
# Out:
# 0        9.722213
# 1        9.743874
# 2        9.766758
# 3        9.781263
# 4        9.781263
#            ...
# 49924    4.052711
# 49925    5.130811
# 49926    4.951017
# 49927    2.865505
# 49928    3.465309
# Name: PM25, Length: 49929, dtype: float64
